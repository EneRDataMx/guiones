# %%
# from IPython.display import Markdown, display

# display(Markdown("000_independencia_energetica.md"))

# %%
import altair as alt
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser  import parse

import matplotlib as mpl

mpl.rcParams.keys()

mpl.rcParams['lines.linewidth']         = 2
mpl.rcParams['lines.markersize']        = 10
mpl.rcParams['lines.markerfacecolor']   = "white"
mpl.rcParams['font.family']             = 'sans-serif'
mpl.rcParams['font.sans-serif']         = "Tahoma"
mpl.rcParams['font.size']               = 18

# mpl.rcParams['lines.linestyle'] = '--'

# %%
f   = 'PlantasSolares.xlsx'
ps = pd.read_excel(f,skiprows=1,skipfooter=4,index_col=[1])
ps.columns
# Out:
# Index(['Empresa', 'Unnamed: 2', 'Nombre del colector', 'Tipo de colector',
#        'Area instalada (gross), m2', 'Área instalada (apertura), m2',
#        'Installed thermal power , kWth',
#        'Solar collector loop heat transfer fluid', 'Solar energy storage',
#        'Storage volume, m³', 'Kind of conventional heat source',
#        'Kind of fuel used'],
#       dtype='object')

# %%
ps['Area instalada (gross), m2'].groupby(by=[ps.index]).sum().cumsum()
# Out:
# Inicio de operación
# 2012      401.10
# 2013      844.78
# 2014     3368.37
# 2015     8325.36
# 2016     8563.46
# 2017    15590.20
# 2018    16002.60
# 2019    16382.60
# Name: Area instalada (gross), m2, dtype: float64

# %%
fig, ax = plt.subplots(constrained_layout=True,figsize=(8,4))


ax.plot(ps['Area instalada (gross), m2'].groupby(by=[ps.index]).sum().cumsum(), '-o',
        label="Area instalada")

ax.set_ylabel("Área  [$m^2$]")
ax.set_xlabel('Año')
ax.spines[['top','right']].set_visible(False)
plt.savefig('AreaInstalada.png')

# %%
fig, ax = plt.subplots(constrained_layout=True,figsize=(8,4))


ax.plot(ps['Installed thermal power , kWth'].groupby(by=[ps.index]).sum().cumsum(), '-o',
        label="Area instalada")


ax.set_ylabel("PTI [$kWh$]")
ax.set_xlabel('Año')
ax.spines[['top','right']].set_visible(False)
plt.savefig('PotenciaTermicaInstalada.png')

# %%
fig, ax = plt.subplots(constrained_layout=True,figsize=(8,4))

base = ps['Installed thermal power , kWth'].groupby(by=[ps.index]).sum().cumsum().iloc[0]

ax.plot(ps['Installed thermal power , kWth'].groupby(by=[ps.index]).sum().cumsum()/base, '-o',
        label="Area instalada")


ax.spines[['top','right']].set_visible(False)

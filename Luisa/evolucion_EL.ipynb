# %%
import pandas as pd
import seaborn as sns

# %%
f = '../data/ER_2015_2020.csv'

ER = pd.read_csv(f)

sns.set_theme(style="whitegrid")

g = sns.catplot(
    data=EL, kind="bar",
    x="Año", y="Porcentaje ER", 
    palette="dark", alpha=.6, height=6
)
g.despine(left=True)

# %%
f = '../data/EL_2015_2020.csv'

EL = pd.read_csv(f)

sns.set_theme(style="whitegrid")

g = sns.catplot(
    data=EL, kind="bar",
    x="Año", y="Porcentaje EL", 
    palette="dark", alpha=.6, height=6
)
g.despine(left=True)

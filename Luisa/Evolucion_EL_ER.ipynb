# %% [markdown]
# <a href="https://colab.research.google.com/github/EneRDataMx/guiones/blob/main/Luisa/Evolucion_EL_ER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
f = 'https://raw.githubusercontent.com/EneRDataMx/guiones/main/data/ER_EL_2015_2020.csv'

data = pd.read_csv(f)
data
# Out:
#     Año  Porcentaje ER  Porcentaje EL
# 0  2015          15.36          20.34
# 1  2016          15.41          20.31
# 2  2017          15.51          20.82
# 3  2018          17.19          22.17
# 4  2019          17.33          21.80
# 5  2020          20.67          25.50

# %%
data = pd.read_csv(f)
ind = data
data.set_index('Año', inplace= True)
data
# Out:
#       Porcentaje ER  Porcentaje EL
# Año
# 2015          15.36          20.34
# 2016          15.41          20.31
# 2017          15.51          20.82
# 2018          17.19          22.17
# 2019          17.33          21.80
# 2020          20.67          25.50

# %%
fig, ax = plt.subplots(constrained_layout=True)

ax.plot(ind["Porcentaje ER"], '-o', color = '#96c120',
        label="Evolución ER")

ax.plot(ind["Porcentaje EL"],'-o', color = '#8990a2', 
        label="Evolución EL")

ax.set_ylabel("Porcentaje")
ax.set_xlabel("Año")
ax.set_ylim(10,35)
ax.legend()
plt.savefig("Evolucion_EL_ER.jpg")
